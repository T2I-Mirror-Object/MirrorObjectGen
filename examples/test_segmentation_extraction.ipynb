# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                   /home/ltnghia02/miniconda3
# QVLM                   /home/ltnghia02/miniconda3/envs/QVLM
# fit3d                  /home/ltnghia02/miniconda3/envs/fit3d
# lodge                  /home/ltnghia02/miniconda3/envs/lodge
# repose                 /home/ltnghia02/miniconda3/envs/repose
# smplpytorch            /home/ltnghia02/miniconda3/envs/smplpytorch
# alphapose              /raid/ltnghia02/conda/envs/alphapose
# bailando               /raid/ltnghia02/conda/envs/bailando
# dance_gen_data         /raid/ltnghia02/conda/envs/dance_gen_data
# extract                /raid/ltnghia02/conda/envs/extract
# mic                    /raid/ltnghia02/conda/envs/mic
# mirrorgen            * /raid/ltnghia02/conda/envs/mirrorgen
# motionbert             /raid/ltnghia02/conda/envs/motionbert
# seg2any                /raid/ltnghia02/conda/envs/seg2any
# zalo                   /raid/ltnghia02/conda/envs/zalo
